# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Aim is to predict the marks of students of the test data

# %%
data = pd.read_excel('training data.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   internet    1000 non-null   object
#  1   sex         1000 non-null   object
#  2   traveltime  1000 non-null   int64
#  3   studytime   1000 non-null   int64
#  4   freetime    1000 non-null   int64
#  5   absences    1000 non-null   int64
#  6   age         1000 non-null   int64
#  7   iq          1000 non-null   int64
#  8   marks       1000 non-null   float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 70.4+ KB

# %%
data.head()
# Out:
#   internet sex  traveltime  studytime  freetime  absences  age   iq  marks
# 0       no   M           2          2         5         6   18  118  73.13
# 1      yes   M           2          2         2         7   19  107  67.78
# 2      yes   M           3          3         3         5   18  108  70.84
# 3       no   F           3          3         4         9   17  100  66.68
# 4      yes   M           1          4         3         4   19   96  71.88

# %% [markdown]
# # comparision of male vs female

# %%
gender_counts = data['sex'].value_counts()

# %%
plt.figure(figsize=(8, 8))
colors = sns.color_palette('pastel')[0:2]
plt.pie(gender_counts, labels=gender_counts.index, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Men vs Women')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='sex', y='marks', data=data, palette='pastel')
plt.xlabel('Sex')
plt.ylabel('Marks')
plt.title('Marks Scored by Men vs Women')
plt.show()

# %% [markdown]
# # comparision of study time vs marks

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='studytime', y='marks', data=data, palette='pastel')
plt.xlabel('Study Time (hours)')
plt.ylabel('Marks')
plt.title('Marks Distribution by Study Time')
plt.show()

# %% [markdown]
# ## Is there any benifit from internet

# %%
internet_avl_counts = data['internet'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=internet_avl_counts.index, y=internet_avl_counts.values, palette='pastel')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Count of Each Age')
for index, value in enumerate(internet_avl_counts):
    plt.text(index, value + 0.1, str(value), ha='center')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='internet', y='marks', data=data, palette='pastel')
plt.xlabel('Availability')
plt.ylabel('Marks')
plt.title('  Is there benefit of internet')
plt.show()

# %% [markdown]
# ## comparisison of age

# %%
distinct_ages = data['age'].unique()
print("Distinct values of age:", distinct_ages)
# Out:
# Distinct values of age: [18 19 17]

# %%
age_counts = data['age'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=age_counts.index, y=age_counts.values, palette='pastel')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Count of Each Age')
for index, value in enumerate(age_counts):
    plt.text(index, value + 0.1, str(value), ha='center')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='age', y='marks', data=data, palette='pastel')
plt.xlabel('Age (years)')
plt.ylabel('Marks')
plt.title('Marks Distribution by age')
plt.show()

# %% [markdown]
# # IQ vs marks

# %%
# Plot the scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.scatterplot(x='iq', y='marks', data=data, palette='pastel', s=100)
sns.regplot(x='iq', y='marks', data=data, scatter=False, color='blue')
plt.xlabel('IQ')
plt.ylabel('Marks')
plt.title('IQ vs Marks')
plt.show()

# %% [markdown]
# # Absents vs Marks

# %%
distinct_absent = data['absences'].unique()
print("Distinct values of absents:", distinct_absent)
# Out:
# Distinct values of absents: [6 7 5 9 4 1 3 2 8]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='absences', y='marks', data=data, palette='pastel')
plt.xlabel('Number of Absents')
plt.ylabel('Marks')
plt.title('Effect of Number of Absents on Marks')
plt.show()

# %%
absent_counts = data['absences'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=absent_counts.index, y=absent_counts.values, palette='pastel')
plt.xlabel('Absent in days')
plt.ylabel('Count')
plt.title('Count of absences')
for index, value in enumerate(absent_counts):
    plt.text(index, value + 0.1, str(value), ha='center')
plt.show()

# %% [markdown]
# # freetime VS Marks

# %%
distinct_freetime = data['freetime'].unique()
print("Distinct values of freetime:", distinct_freetime)
# Out:
# Distinct values of freetime: [5 2 3 4 1]

# %%
freetime_counts = data['freetime'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=freetime_counts.index, y=freetime_counts.values, palette='pastel')
plt.xlabel('freetime in hours')
plt.ylabel('Count')
plt.title('freetime availabe')
for index, value in enumerate(freetime_counts):
    plt.text(index, value + 0.1, str(value), ha='center')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='freetime', y='marks', data=data, palette='pastel')
plt.xlabel('hours of free time')
plt.ylabel('Marks')
plt.title('free time vs Marks')
plt.show()

# %% [markdown]
# # Travel time vs marks

# %%
distinct_traveltime = data['traveltime'].unique()
print("Distinct values of traveltime:", distinct_traveltime)
# Out:
# Distinct values of traveltime: [2 3 1 4]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='traveltime', y='marks', data=data, palette='pastel')
plt.xlabel('hours of travel time')
plt.ylabel('Marks')
plt.title('travel time vs Marks')
plt.show()

# %%
data.head()
# Out:
#   internet sex  traveltime  studytime  freetime  absences  age   iq  marks
# 0       no   M           2          2         5         6   18  118  73.13
# 1      yes   M           2          2         2         7   19  107  67.78
# 2      yes   M           3          3         3         5   18  108  70.84
# 3       no   F           3          3         4         9   17  100  66.68
# 4      yes   M           1          4         3         4   19   96  71.88

# %%
# Use the file namd 'training data' to train the model
x_train = np.array(data.iloc[:,0:8])
y_train = np.array(data.iloc[:,8]).reshape(-1,1)

# %%
# Try plotting y_train with different features
# To get an idea whether to add some features or not
# Add some features if required in x_train

# Also do label encoding for features not represented in numbers
# refer the link if not know : https://youtu.be/589nCGeWG1w?si=t2Wa7LgbUOO4RooM

# %%
def feature_changing(x_train):
    sex_map = {'M': 1, 'F': 0}
    x_train[:, 1] = np.vectorize(sex_map.get)(x_train[:, 1])
    internet_map = {'yes': 1, 'no': 0}
    x_train[:, 0] = np.vectorize(internet_map.get)(x_train[:, 0])
    return x_train
x_train = feature_changing(x_train)

# %%
def z_score(x_train):
    x_mean = np.mean(x_train, axis=0)
    x_std = np.std(x_train, axis=0)
    x_train = (x_train - x_mean) / x_std
    return x_train, x_std, x_mean

# %%
x_train.shape
# Out:
# (1000, 8)

# %%
def cost(x_train, y_train, w, b):
    m = x_train.shape[0]
    predictions = np.dot(x_train, w) + b
    squared_errors = (predictions - y_train) ** 2
    mse = np.sum(squared_errors) /m
    return mse

# %%
def gradient_descent(x_train, y_train, w, b, learning_rate=0.001, num_iterations=1000):
    predictions = np.dot(x_train, w) + b
    errors = predictions - y_train
    dw = np.dot(x_train.T, errors)
    db = np.sum(errors)
    w = w - learning_rate * dw
    b = b - learning_rate * db
    return w, b

# %%
x_train = x_train.astype(np.float64)
x_train,x_std,x_mean = z_score(x_train)

# %%
np.random.seed(2147483647)
w = np.random.randn(x_train.shape[1],1)
b = np.random.randn(1)

# %%
old_cost = 0

# %%
n=0

# %%
while abs(old_cost - cost(x_train,y_train,w,b))>0.00001:
   n = n+1
   old_cost = cost(x_train,y_train,w,b)
   w,b = gradient_descent(x_train,y_train,w,b)
   print(old_cost)
print(n)
# Out:
# 4987.357715515591
# 0.14044034629745622
# 0.0006025488959066074
# 1.5247701254767366e-05
# 4

# %%
print(old_cost)
# Out:
# 1.5247701254767366e-05

# %%
x_predict = pd.read_excel('Test data.xlsx').iloc[:,:8].to_numpy()
print(x_predict[2])
# Out:
# ['no' 'M' 2 4 4 7 18 114]

# %%
x_predict = feature_changing(x_predict)
print(x_predict[2])
# Out:
# [0 1 2 4 4 7 18 114]

# %%
x_predict = (x_predict - x_mean)/x_std
print(x_predict[2])
# Out:
# [-1.4644637544337908 0.8562139061198019 0.2867665212851301
#  2.0567400343056685 0.6378747689215618 0.7514383860953198
#  0.033180738485371154 0.42756308052321185]

# %%
ans = pd.read_excel('Test data.xlsx').iloc[:,8].to_numpy()

# %%
ans
# Out:
# array([74.59, 65.28, 79.24, 62.66, 67.83, 75.43, 77.06, 75.94, 72.51,
#        71.61, 65.03, 59.09, 70.  , 59.06, 70.12, 74.39, 57.71, 79.34,
#        57.53, 60.87, 74.7 , 63.7 , 79.42, 64.52, 79.52, 85.41, 68.14,
#        68.28, 62.31, 82.25, 61.25, 69.06, 78.41, 75.8 , 80.11, 69.74,
#        77.03, 75.4 , 78.28, 68.64, 69.31, 61.77, 77.7 , 74.53, 67.64,
#        64.56, 66.14, 71.91, 75.15, 74.1 , 62.4 , 64.43, 75.73, 71.52,
#        80.92, 61.66, 71.93, 85.24, 70.31, 79.31, 69.65, 70.62, 68.92,
#        75.74, 62.7 , 74.38, 64.18, 65.25, 63.89, 74.55, 68.26, 76.65,
#        62.56, 58.36, 67.91, 65.81, 63.33, 64.3 , 55.68, 72.48, 74.13,
#        65.27, 58.4 , 76.02, 71.63, 68.84, 61.17, 68.72, 60.04, 60.18,
#        79.69, 72.6 , 74.78, 75.17, 75.78, 80.77, 83.91, 78.67, 67.94,
#        59.27, 68.67, 74.25, 77.95, 78.71, 70.18, 79.5 , 73.89, 75.22,
#        71.59, 71.15, 62.72, 69.8 , 80.18, 80.08, 69.25, 72.17, 60.44,
# ...

# %%
y_predict = np.dot(x_predict,w) + b

# %%
y_predict
# Out:
# array([[74.5963354030032],
#        [65.28484288111537],
#        [79.23640565310018],
#        [62.65799382844461],
#        [67.82605970689875],
#        [75.4263943341618],
#        [77.05729290497729],
#        [75.9457319770378],
#        [72.51070150786623],
#        [71.60586873060154],
#        [65.0385181701178],
#        [59.086083922787004],
#        [70.00667873926378],
#        [59.06262910600577],
#        [70.12060563017971],
#        [74.38731102582456],
#        [57.707448995328285],
#        [79.33689334012138],
#        [57.532951677204075],
#        [60.874009919246404],
#        [74.70256085097313],
#        [63.70587965467219],
#        [79.42101204654846],
#        [64.51612840917527],
#        [79.51580965936435],
#        [85.40605247028496],
#        [68.13675809253614],
#        [68.27720013424421],
#        [62.30800438162269],
#        [82.25507830860263],
#        [61.25136975770565],
#        [69.06267531213608],
#        [78.41059828800596],
# ...

# %%
len(ans)
# Out:
# 200

# %%
accuracy = 0
for dim in range(len(ans)):
  if abs(y_predict[dim]-ans[dim])<0.5: # do not change the tolerance as you'll be checked on +- 0.5 error only
    accuracy += 1

# %%
accuracy
# Out:
# 200

# %%
accuracy = round(accuracy*100/200.0,2)
ok = 'Congratulations' if accuracy>95 else 'Optimization required'
print(f"{ok}, your accuracy is {accuracy}%")
# Out:
# Congratulations, your accuracy is 100.0%
